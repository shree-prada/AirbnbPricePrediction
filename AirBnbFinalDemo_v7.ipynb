# %%
import os
import pandas as pd
import numpy as np

# %%
# Specify the folder path where the CSV files are located..
path1 = "I:/class/Term2/BDM 3014/Project/CSVs/Batch1"
# Create an empty list to store the DataFrames
dataframes1 = []
# Iterate through all files in the folder
for file_name in os.listdir(path1):
    if file_name.endswith(".csv"):
        # Read each CSV file into a DataFrame
        file_path1 = os.path.join(path1, file_name)
        df1= pd.read_csv(file_path1,low_memory=False)
        dataframes1.append(df1)
# Concatenate all DataFrames into a single DataFrame
combine1 = pd.concat(dataframes1, ignore_index=True)
#printing the shape.
print(combine1.shape)
# Out:
# (197132, 75)

# %%
# Specify the folder path where the CSV files are located
path2 = "I:/class/Term2/BDM 3014/Project/CSVs/Batch2"
# Create an empty list to store the DataFrames
dataframes2 = []
# Iterate through all files in the folder
for file_name in os.listdir(path2):
    if file_name.endswith(".csv"):
        # Read each CSV file into a DataFrame
        file_path2 = os.path.join(path2, file_name)
        df2= pd.read_csv(file_path2,low_memory=False)
        dataframes2.append(df2)
# Concatenate all DataFrames into a single DataFrame
combine2 = pd.concat(dataframes2, ignore_index=True)
print(combine2.shape)
# Out:
# (388021, 75)

# %%
# Concatenate all combined dataframes into a single final combined DataFrame
FinalDFList=[]
FinalDFList.append(combine1)
#FinalDFList.append(combine2)
FinalCombo = pd.concat(FinalDFList, ignore_index=True)
print(FinalCombo.shape)
#print(FinalCombo[['host_location']].head(50))
# Out:
# (197132, 75)

# %%
#Making CSV from the final dataset
subset_df = FinalCombo.tail(80000)
print(subset_df.shape)
# Out:
# (80000, 75)

# %%
#dropping irrelavant columns
subset_df.drop(columns=['id', 'last_scraped', 'listing_url','scrape_id','source','name','description','neighborhood_overview','picture_url','host_id','host_url','host_name','host_since','host_about','host_thumbnail_url','host_picture_url','host_neighbourhood','host_verifications','neighbourhood','neighbourhood_cleansed','neighbourhood_group_cleansed','latitude','longitude','bathrooms','bathrooms_text','amenities','calendar_updated','calendar_last_scraped','first_review','last_review','license'],inplace=True)

#remove records having blank host locations
subset_df.dropna(subset=['host_location'], inplace=True)

#check how many Null values we have in each feature
for col in subset_df.columns:
    print(col + ', Number of Missing Values:', len(subset_df[col][subset_df[col].isnull()]))

#fill missing values with mode values of fatures
mode_values = subset_df.mode().iloc[0]
columns_to_fill = subset_df.columns
subset_df[columns_to_fill] = subset_df[columns_to_fill].fillna(mode_values)

subset_df.drop(columns=['host_location'],inplace=True)

print("\n\n")
for col in subset_df.columns:
    print(col + ', Number of Missing Values:', len(subset_df[col][subset_df[col].isnull()]))
# Out:
# host_location, Number of Missing Values: 0
# host_response_time, Number of Missing Values: 10355
# host_response_rate, Number of Missing Values: 10355
# host_acceptance_rate, Number of Missing Values: 6611
# host_is_superhost, Number of Missing Values: 9138
# host_listings_count, Number of Missing Values: 0
# host_total_listings_count, Number of Missing Values: 0
# host_has_profile_pic, Number of Missing Values: 0
# host_identity_verified, Number of Missing Values: 0
# property_type, Number of Missing Values: 0
# room_type, Number of Missing Values: 0
# accommodates, Number of Missing Values: 0
# bedrooms, Number of Missing Values: 13563
# beds, Number of Missing Values: 674
# price, Number of Missing Values: 0
# minimum_nights, Number of Missing Values: 0
# maximum_nights, Number of Missing Values: 0
# minimum_minimum_nights, Number of Missing Values: 14
# maximum_minimum_nights, Number of Missing Values: 14
# minimum_maximum_nights, Number of Missing Values: 14
# maximum_maximum_nights, Number of Missing Values: 14
# minimum_nights_avg_ntm, Number of Missing Values: 14
# maximum_nights_avg_ntm, Number of Missing Values: 14
# has_availability, Number of Missing Values: 0
# availability_30, Number of Missing Values: 0
# availability_60, Number of Missing Values: 0
# availability_90, Number of Missing Values: 0
# availability_365, Number of Missing Values: 0
# number_of_reviews, Number of Missing Values: 0
# number_of_reviews_ltm, Number of Missing Values: 0
# number_of_reviews_l30d, Number of Missing Values: 0
# review_scores_rating, Number of Missing Values: 10686
# review_scores_accuracy, Number of Missing Values: 10882
# review_scores_cleanliness, Number of Missing Values: 10881
# review_scores_checkin, Number of Missing Values: 10889
# review_scores_communication, Number of Missing Values: 10882
# review_scores_location, Number of Missing Values: 10888
# review_scores_value, Number of Missing Values: 10887
# instant_bookable, Number of Missing Values: 0
# calculated_host_listings_count, Number of Missing Values: 0
# calculated_host_listings_count_entire_homes, Number of Missing Values: 0
# calculated_host_listings_count_private_rooms, Number of Missing Values: 0
# calculated_host_listings_count_shared_rooms, Number of Missing Values: 0
# reviews_per_month, Number of Missing Values: 10686
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\1844153678.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df.drop(columns=['id', 'last_scraped', 'listing_url','scrape_id','source','name','description','neighborhood_overview','picture_url','host_id','host_url','host_name','host_since','host_about','host_thumbnail_url','host_picture_url','host_neighbourhood','host_verifications','neighbourhood','neighbourhood_cleansed','neighbourhood_group_cleansed','latitude','longitude','bathrooms','bathrooms_text','amenities','calendar_updated','calendar_last_scraped','first_review','last_review','license'],inplace=True)
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\1844153678.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df.dropna(subset=['host_location'], inplace=True)
# host_response_time, Number of Missing Values: 0
# host_response_rate, Number of Missing Values: 0
# host_acceptance_rate, Number of Missing Values: 0
# host_is_superhost, Number of Missing Values: 0
# host_listings_count, Number of Missing Values: 0
# host_total_listings_count, Number of Missing Values: 0
# host_has_profile_pic, Number of Missing Values: 0
# host_identity_verified, Number of Missing Values: 0
# property_type, Number of Missing Values: 0
# room_type, Number of Missing Values: 0
# accommodates, Number of Missing Values: 0
# bedrooms, Number of Missing Values: 0
# beds, Number of Missing Values: 0
# price, Number of Missing Values: 0
# minimum_nights, Number of Missing Values: 0
# maximum_nights, Number of Missing Values: 0
# minimum_minimum_nights, Number of Missing Values: 0
# maximum_minimum_nights, Number of Missing Values: 0
# minimum_maximum_nights, Number of Missing Values: 0
# maximum_maximum_nights, Number of Missing Values: 0
# minimum_nights_avg_ntm, Number of Missing Values: 0
# maximum_nights_avg_ntm, Number of Missing Values: 0
# has_availability, Number of Missing Values: 0
# availability_30, Number of Missing Values: 0
# availability_60, Number of Missing Values: 0
# availability_90, Number of Missing Values: 0
# availability_365, Number of Missing Values: 0
# number_of_reviews, Number of Missing Values: 0
# number_of_reviews_ltm, Number of Missing Values: 0
# number_of_reviews_l30d, Number of Missing Values: 0
# review_scores_rating, Number of Missing Values: 0
# review_scores_accuracy, Number of Missing Values: 0
# review_scores_cleanliness, Number of Missing Values: 0
# review_scores_checkin, Number of Missing Values: 0
# review_scores_communication, Number of Missing Values: 0
# review_scores_location, Number of Missing Values: 0
# review_scores_value, Number of Missing Values: 0
# instant_bookable, Number of Missing Values: 0
# calculated_host_listings_count, Number of Missing Values: 0
# calculated_host_listings_count_entire_homes, Number of Missing Values: 0
# calculated_host_listings_count_private_rooms, Number of Missing Values: 0
# calculated_host_listings_count_shared_rooms, Number of Missing Values: 0
# reviews_per_month, Number of Missing Values: 0
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\1844153678.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df[columns_to_fill] = subset_df[columns_to_fill].fillna(mode_values)
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\1844153678.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df.drop(columns=['host_location'],inplace=True)

# %%
#checking for feature types
for col in subset_df.columns:
    data_type = subset_df[col].dtype
    print(f"The data type of column '{col}' is {data_type}.")
# Out:
# The data type of column 'host_response_time' is object.
# The data type of column 'host_response_rate' is object.
# The data type of column 'host_acceptance_rate' is object.
# The data type of column 'host_is_superhost' is object.
# The data type of column 'host_listings_count' is float64.
# The data type of column 'host_total_listings_count' is float64.
# The data type of column 'host_has_profile_pic' is object.
# The data type of column 'host_identity_verified' is object.
# The data type of column 'property_type' is object.
# The data type of column 'room_type' is object.
# The data type of column 'accommodates' is int64.
# The data type of column 'bedrooms' is float64.
# The data type of column 'beds' is float64.
# The data type of column 'price' is object.
# The data type of column 'minimum_nights' is int64.
# The data type of column 'maximum_nights' is int64.
# The data type of column 'minimum_minimum_nights' is float64.
# The data type of column 'maximum_minimum_nights' is float64.
# The data type of column 'minimum_maximum_nights' is float64.
# The data type of column 'maximum_maximum_nights' is float64.
# The data type of column 'minimum_nights_avg_ntm' is float64.
# The data type of column 'maximum_nights_avg_ntm' is float64.
# The data type of column 'has_availability' is object.
# The data type of column 'availability_30' is int64.
# The data type of column 'availability_60' is int64.
# The data type of column 'availability_90' is int64.
# The data type of column 'availability_365' is int64.
# The data type of column 'number_of_reviews' is int64.
# The data type of column 'number_of_reviews_ltm' is int64.
# The data type of column 'number_of_reviews_l30d' is int64.
# The data type of column 'review_scores_rating' is float64.
# The data type of column 'review_scores_accuracy' is float64.
# The data type of column 'review_scores_cleanliness' is float64.
# The data type of column 'review_scores_checkin' is float64.
# The data type of column 'review_scores_communication' is float64.
# The data type of column 'review_scores_location' is float64.
# The data type of column 'review_scores_value' is float64.
# The data type of column 'instant_bookable' is object.
# The data type of column 'calculated_host_listings_count' is int64.
# The data type of column 'calculated_host_listings_count_entire_homes' is int64.
# The data type of column 'calculated_host_listings_count_private_rooms' is int64.
# The data type of column 'calculated_host_listings_count_shared_rooms' is int64.
# The data type of column 'reviews_per_month' is float64.

# %%
#preprocess the features needed
subset_df["host_response_rate"] = subset_df["host_response_rate"].str.replace("%", "")
subset_df["host_acceptance_rate"] = subset_df["host_acceptance_rate"].str.replace("%", "")
subset_df["price"] = subset_df["price"].str.replace("$", "")

#change the feature types
#subset_df['host_location'] = subset_df['host_location'].astype(pd.StringDtype())
subset_df['host_response_time'] = subset_df['host_response_time'].astype(pd.StringDtype())
subset_df['host_is_superhost'] = subset_df['host_is_superhost'].astype(pd.StringDtype())
subset_df['host_has_profile_pic'] = subset_df['host_has_profile_pic'].astype(pd.StringDtype())
subset_df['host_identity_verified'] = subset_df['host_identity_verified'].astype(pd.StringDtype())
subset_df['property_type'] = subset_df['property_type'].astype(pd.StringDtype())
subset_df['room_type'] = subset_df['room_type'].astype(pd.StringDtype())
subset_df['has_availability'] = subset_df['has_availability'].astype(pd.StringDtype())
subset_df['instant_bookable'] = subset_df['instant_bookable'].astype(pd.StringDtype())
subset_df['price'] = pd.to_numeric(subset_df["price"], errors='coerce').astype(pd.Int64Dtype())
subset_df["host_response_rate"] = pd.to_numeric(subset_df["host_response_rate"], errors='coerce').astype(pd.Int64Dtype())
subset_df["host_acceptance_rate"] = pd.to_numeric(subset_df["host_acceptance_rate"], errors='coerce').astype(pd.Int64Dtype())
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\2998593439.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df["host_response_rate"] = subset_df["host_response_rate"].str.replace("%", "")
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\2998593439.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df["host_acceptance_rate"] = subset_df["host_acceptance_rate"].str.replace("%", "")
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\2998593439.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df["price"] = subset_df["price"].str.replace("$", "")
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\2998593439.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['host_response_time'] = subset_df['host_response_time'].astype(pd.StringDtype())
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\2998593439.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['host_is_superhost'] = subset_df['host_is_superhost'].astype(pd.StringDtype())
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\2998593439.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['host_has_profile_pic'] = subset_df['host_has_profile_pic'].astype(pd.StringDtype())
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\2998593439.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['host_identity_verified'] = subset_df['host_identity_verified'].astype(pd.StringDtype())
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\2998593439.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['property_type'] = subset_df['property_type'].astype(pd.StringDtype())
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\2998593439.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['room_type'] = subset_df['room_type'].astype(pd.StringDtype())
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\2998593439.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['has_availability'] = subset_df['has_availability'].astype(pd.StringDtype())
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\2998593439.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['instant_bookable'] = subset_df['instant_bookable'].astype(pd.StringDtype())
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\2998593439.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df['price'] = pd.to_numeric(subset_df["price"], errors='coerce').astype(pd.Int64Dtype())
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\2998593439.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df["host_response_rate"] = pd.to_numeric(subset_df["host_response_rate"], errors='coerce').astype(pd.Int64Dtype())
# C:\Users\patel\AppData\Local\Temp\ipykernel_19364\2998593439.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df["host_acceptance_rate"] = pd.to_numeric(subset_df["host_acceptance_rate"], errors='coerce').astype(pd.Int64Dtype())

# %%
#checking for feature types
for col in subset_df.columns:
    data_type = subset_df[col].dtype
    print(f"The data type of column '{col}' is {data_type}.")
# Out:
# The data type of column 'host_response_time' is string.
# The data type of column 'host_response_rate' is Int64.
# The data type of column 'host_acceptance_rate' is Int64.
# The data type of column 'host_is_superhost' is string.
# The data type of column 'host_listings_count' is float64.
# The data type of column 'host_total_listings_count' is float64.
# The data type of column 'host_has_profile_pic' is string.
# The data type of column 'host_identity_verified' is string.
# The data type of column 'property_type' is string.
# The data type of column 'room_type' is string.
# The data type of column 'accommodates' is int64.
# The data type of column 'bedrooms' is float64.
# The data type of column 'beds' is float64.
# The data type of column 'price' is Int64.
# The data type of column 'minimum_nights' is int64.
# The data type of column 'maximum_nights' is int64.
# The data type of column 'minimum_minimum_nights' is float64.
# The data type of column 'maximum_minimum_nights' is float64.
# The data type of column 'minimum_maximum_nights' is float64.
# The data type of column 'maximum_maximum_nights' is float64.
# The data type of column 'minimum_nights_avg_ntm' is float64.
# The data type of column 'maximum_nights_avg_ntm' is float64.
# The data type of column 'has_availability' is string.
# The data type of column 'availability_30' is int64.
# The data type of column 'availability_60' is int64.
# The data type of column 'availability_90' is int64.
# The data type of column 'availability_365' is int64.
# The data type of column 'number_of_reviews' is int64.
# The data type of column 'number_of_reviews_ltm' is int64.
# The data type of column 'number_of_reviews_l30d' is int64.
# The data type of column 'review_scores_rating' is float64.
# The data type of column 'review_scores_accuracy' is float64.
# The data type of column 'review_scores_cleanliness' is float64.
# The data type of column 'review_scores_checkin' is float64.
# The data type of column 'review_scores_communication' is float64.
# The data type of column 'review_scores_location' is float64.
# The data type of column 'review_scores_value' is float64.
# The data type of column 'instant_bookable' is string.
# The data type of column 'calculated_host_listings_count' is int64.
# The data type of column 'calculated_host_listings_count_entire_homes' is int64.
# The data type of column 'calculated_host_listings_count_private_rooms' is int64.
# The data type of column 'calculated_host_listings_count_shared_rooms' is int64.
# The data type of column 'reviews_per_month' is float64.

# %%
#remove duplicates
print(subset_df)
subset_df = subset_df.drop_duplicates()
print(subset_df)
# Out:
#         host_response_time  host_response_rate  host_acceptance_rate
# 117133      within an hour                  94                    99  \
# 117134        within a day                  88                    83
# 117135  within a few hours                 100                    95
# 117136      within an hour                 100                   100
# 117138      within an hour                 100                   100
# ...                    ...                 ...                   ...
# 197125      within an hour                 100                    86
# 197126      within an hour                 100                    88
# 197127      within an hour                 100                   100
# 197129      within an hour                 100                   100
# 197130      within an hour                 100                   100
#
#        host_is_superhost  host_listings_count  host_total_listings_count
# 117133                 t                 42.0                       52.0  \
# 117134                 f                  1.0                        3.0
# 117135                 f                  2.0                        2.0
# 117136                 f                  1.0                        2.0
# 117138                 f                  1.0                        1.0
# ...                  ...                  ...                        ...
# 197125                 t                 24.0                       30.0
# 197126                 t                 17.0                       53.0
# 197127                 f                  2.0                        3.0
# 197129                 f                  1.0                        2.0
# 197130                 f                  6.0                        6.0
#
#        host_has_profile_pic host_identity_verified       property_type
# 117133                    t                      t  Entire rental unit  \
# 117134                    t                      t  Entire rental unit
# 117135                    t                      t    Entire townhouse
# 117136                    t                      t  Entire rental unit
# 117138                    t                      t         Entire home
# ...                     ...                    ...                 ...
# 197125                    t                      t  Entire rental unit
# 197126                    t                      t  Entire rental unit
# 197127                    t                      t  Entire rental unit
# 197129                    t                      t    Entire townhouse
# 197130                    t                      t         Entire home
#
#               room_type  ...  review_scores_checkin
# 117133  Entire home/apt  ...                    5.0  \
# 117134  Entire home/apt  ...                    5.0
# 117135  Entire home/apt  ...                    5.0
# 117136  Entire home/apt  ...                    5.0
# 117138  Entire home/apt  ...                    5.0
# ...                 ...  ...                    ...
# 197125  Entire home/apt  ...                    5.0
# 197126  Entire home/apt  ...                    5.0
# 197127  Entire home/apt  ...                    5.0
# 197129  Entire home/apt  ...                    5.0
# 197130  Entire home/apt  ...                    5.0
#
#         review_scores_communication  review_scores_location
# 117133                          5.0                    5.00  \
# 117134                          5.0                    5.00
# 117135                          5.0                    5.00
# 117136                          5.0                    4.33
# 117138                          5.0                    4.00
# ...                             ...                     ...
# 197125                          5.0                    5.00
# 197126                          5.0                    5.00
# 197127                          5.0                    5.00
# 197129                          5.0                    5.00
# 197130                          5.0                    5.00
#
#         review_scores_value  instant_bookable  calculated_host_listings_count
# 117133                 5.00                 f                              41  \
# 117134                 5.00                 f                               1
# 117135                 5.00                 f                               1
# 117136                 5.00                 f                               1
# 117138                 3.67                 t                               1
# ...                     ...               ...                             ...
# 197125                 5.00                 f                              23
# 197126                 5.00                 f                              17
# 197127                 5.00                 f                               2
# 197129                 5.00                 f                               1
# 197130                 5.00                 t                               5
#
#         calculated_host_listings_count_entire_homes
# 117133                                           41  \
# 117134                                            1
# 117135                                            1
# 117136                                            1
# 117138                                            1
# ...                                             ...
# 197125                                           23
# 197126                                           17
# 197127                                            2
# 197129                                            1
# 197130                                            3
#
#         calculated_host_listings_count_private_rooms
# 117133                                             0  \
# 117134                                             0
# 117135                                             0
# 117136                                             0
# 117138                                             0
# ...                                              ...
# 197125                                             0
# 197126                                             0
# 197127                                             0
# 197129                                             0
# 197130                                             2
#
#         calculated_host_listings_count_shared_rooms  reviews_per_month
# 117133                                            0               1.00
# 117134                                            0               1.00
# 117135                                            0               1.00
# 117136                                            0               1.38
# 117138                                            0               2.09
# ...                                             ...                ...
# 197125                                            0               1.00
# 197126                                            0               1.00
# 197127                                            0               1.00
# 197129                                            0               1.00
# 197130                                            0               1.00
#
# [61686 rows x 43 columns]
#         host_response_time  host_response_rate  host_acceptance_rate
# 117133      within an hour                  94                    99  \
# 117134        within a day                  88                    83
# 117135  within a few hours                 100                    95
# 117136      within an hour                 100                   100
# 117138      within an hour                 100                   100
# ...                    ...                 ...                   ...
# 197125      within an hour                 100                    86
# 197126      within an hour                 100                    88
# 197127      within an hour                 100                   100
# 197129      within an hour                 100                   100
# 197130      within an hour                 100                   100
#
#        host_is_superhost  host_listings_count  host_total_listings_count
# 117133                 t                 42.0                       52.0  \
# 117134                 f                  1.0                        3.0
# 117135                 f                  2.0                        2.0
# 117136                 f                  1.0                        2.0
# 117138                 f                  1.0                        1.0
# ...                  ...                  ...                        ...
# 197125                 t                 24.0                       30.0
# 197126                 t                 17.0                       53.0
# 197127                 f                  2.0                        3.0
# 197129                 f                  1.0                        2.0
# 197130                 f                  6.0                        6.0
#
#        host_has_profile_pic host_identity_verified       property_type
# 117133                    t                      t  Entire rental unit  \
# 117134                    t                      t  Entire rental unit
# 117135                    t                      t    Entire townhouse
# 117136                    t                      t  Entire rental unit
# 117138                    t                      t         Entire home
# ...                     ...                    ...                 ...
# 197125                    t                      t  Entire rental unit
# 197126                    t                      t  Entire rental unit
# 197127                    t                      t  Entire rental unit
# 197129                    t                      t    Entire townhouse
# 197130                    t                      t         Entire home
#
#               room_type  ...  review_scores_checkin
# 117133  Entire home/apt  ...                    5.0  \
# 117134  Entire home/apt  ...                    5.0
# 117135  Entire home/apt  ...                    5.0
# 117136  Entire home/apt  ...                    5.0
# 117138  Entire home/apt  ...                    5.0
# ...                 ...  ...                    ...
# 197125  Entire home/apt  ...                    5.0
# 197126  Entire home/apt  ...                    5.0
# 197127  Entire home/apt  ...                    5.0
# 197129  Entire home/apt  ...                    5.0
# 197130  Entire home/apt  ...                    5.0
#
#         review_scores_communication  review_scores_location
# 117133                          5.0                    5.00  \
# 117134                          5.0                    5.00
# 117135                          5.0                    5.00
# 117136                          5.0                    4.33
# 117138                          5.0                    4.00
# ...                             ...                     ...
# 197125                          5.0                    5.00
# 197126                          5.0                    5.00
# 197127                          5.0                    5.00
# 197129                          5.0                    5.00
# 197130                          5.0                    5.00
#
#         review_scores_value  instant_bookable  calculated_host_listings_count
# 117133                 5.00                 f                              41  \
# 117134                 5.00                 f                               1
# 117135                 5.00                 f                               1
# 117136                 5.00                 f                               1
# 117138                 3.67                 t                               1
# ...                     ...               ...                             ...
# 197125                 5.00                 f                              23
# 197126                 5.00                 f                              17
# 197127                 5.00                 f                               2
# 197129                 5.00                 f                               1
# 197130                 5.00                 t                               5
#
#         calculated_host_listings_count_entire_homes
# 117133                                           41  \
# 117134                                            1
# 117135                                            1
# 117136                                            1
# 117138                                            1
# ...                                             ...
# 197125                                           23
# 197126                                           17
# 197127                                            2
# 197129                                            1
# 197130                                            3
#
#         calculated_host_listings_count_private_rooms
# 117133                                             0  \
# 117134                                             0
# 117135                                             0
# 117136                                             0
# 117138                                             0
# ...                                              ...
# 197125                                             0
# 197126                                             0
# 197127                                             0
# 197129                                             0
# 197130                                             2
#
#         calculated_host_listings_count_shared_rooms  reviews_per_month
# 117133                                            0               1.00
# 117134                                            0               1.00
# 117135                                            0               1.00
# 117136                                            0               1.38
# 117138                                            0               2.09
# ...                                             ...                ...
# 197125                                            0               1.00
# 197126                                            0               1.00
# 197127                                            0               1.00
# 197129                                            0               1.00
# 197130                                            0               1.00
#
# [61299 rows x 43 columns]

# %%
#differentiate categorical and numerical columns
numeric_columns = subset_df.select_dtypes(include=['int64', 'float64','Int64','Float64']).columns
categorical_columns = set(subset_df.columns) - set(numeric_columns)
print("numeric_columns-->",numeric_columns)
print("categorical_columns-->",categorical_columns)
print(subset_df.shape)
# Out:
# numeric_columns--> Index(['host_response_rate', 'host_acceptance_rate', 'host_listings_count',
#        'host_total_listings_count', 'accommodates', 'bedrooms', 'beds',
#        'price', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')
# categorical_columns--> {'host_is_superhost', 'instant_bookable', 'property_type', 'host_response_time', 'room_type', 'host_identity_verified', 'host_has_profile_pic', 'has_availability'}
# (61299, 43)

# %%
#check how many Null values we have in each feature
for col in subset_df.columns:
    print(col + ', Number of Missing Values:', len(subset_df[col][subset_df[col].isnull()]))

#fill missing values with mode values of fatures
mode_values = subset_df.mode().iloc[0]
columns_to_fill = subset_df.columns
subset_df[columns_to_fill] = subset_df[columns_to_fill].fillna(mode_values)

print("\n\n")
for col in subset_df.columns:
    print(col + ', Number of Missing Values:', len(subset_df[col][subset_df[col].isnull()]))
# Out:
# host_response_time, Number of Missing Values: 0
# host_response_rate, Number of Missing Values: 0
# host_acceptance_rate, Number of Missing Values: 0
# host_is_superhost, Number of Missing Values: 0
# host_listings_count, Number of Missing Values: 0
# host_total_listings_count, Number of Missing Values: 0
# host_has_profile_pic, Number of Missing Values: 0
# host_identity_verified, Number of Missing Values: 0
# property_type, Number of Missing Values: 0
# room_type, Number of Missing Values: 0
# accommodates, Number of Missing Values: 0
# bedrooms, Number of Missing Values: 0
# beds, Number of Missing Values: 0
# price, Number of Missing Values: 29945
# minimum_nights, Number of Missing Values: 0
# maximum_nights, Number of Missing Values: 0
# minimum_minimum_nights, Number of Missing Values: 0
# maximum_minimum_nights, Number of Missing Values: 0
# minimum_maximum_nights, Number of Missing Values: 0
# maximum_maximum_nights, Number of Missing Values: 0
# minimum_nights_avg_ntm, Number of Missing Values: 0
# maximum_nights_avg_ntm, Number of Missing Values: 0
# has_availability, Number of Missing Values: 0
# availability_30, Number of Missing Values: 0
# availability_60, Number of Missing Values: 0
# availability_90, Number of Missing Values: 0
# availability_365, Number of Missing Values: 0
# number_of_reviews, Number of Missing Values: 0
# number_of_reviews_ltm, Number of Missing Values: 0
# number_of_reviews_l30d, Number of Missing Values: 0
# review_scores_rating, Number of Missing Values: 0
# review_scores_accuracy, Number of Missing Values: 0
# review_scores_cleanliness, Number of Missing Values: 0
# review_scores_checkin, Number of Missing Values: 0
# review_scores_communication, Number of Missing Values: 0
# review_scores_location, Number of Missing Values: 0
# review_scores_value, Number of Missing Values: 0
# instant_bookable, Number of Missing Values: 0
# calculated_host_listings_count, Number of Missing Values: 0
# calculated_host_listings_count_entire_homes, Number of Missing Values: 0
# calculated_host_listings_count_private_rooms, Number of Missing Values: 0
# calculated_host_listings_count_shared_rooms, Number of Missing Values: 0
# reviews_per_month, Number of Missing Values: 0
#
#
#
# host_response_time, Number of Missing Values: 0
# host_response_rate, Number of Missing Values: 0
# host_acceptance_rate, Number of Missing Values: 0
# host_is_superhost, Number of Missing Values: 0
# host_listings_count, Number of Missing Values: 0
# host_total_listings_count, Number of Missing Values: 0
# host_has_profile_pic, Number of Missing Values: 0
# host_identity_verified, Number of Missing Values: 0
# property_type, Number of Missing Values: 0
# room_type, Number of Missing Values: 0
# accommodates, Number of Missing Values: 0
# bedrooms, Number of Missing Values: 0
# beds, Number of Missing Values: 0
# price, Number of Missing Values: 0
# minimum_nights, Number of Missing Values: 0
# maximum_nights, Number of Missing Values: 0
# minimum_minimum_nights, Number of Missing Values: 0
# maximum_minimum_nights, Number of Missing Values: 0
# minimum_maximum_nights, Number of Missing Values: 0
# maximum_maximum_nights, Number of Missing Values: 0
# minimum_nights_avg_ntm, Number of Missing Values: 0
# maximum_nights_avg_ntm, Number of Missing Values: 0
# has_availability, Number of Missing Values: 0
# availability_30, Number of Missing Values: 0
# availability_60, Number of Missing Values: 0
# availability_90, Number of Missing Values: 0
# availability_365, Number of Missing Values: 0
# number_of_reviews, Number of Missing Values: 0
# number_of_reviews_ltm, Number of Missing Values: 0
# number_of_reviews_l30d, Number of Missing Values: 0
# review_scores_rating, Number of Missing Values: 0
# review_scores_accuracy, Number of Missing Values: 0
# review_scores_cleanliness, Number of Missing Values: 0
# review_scores_checkin, Number of Missing Values: 0
# review_scores_communication, Number of Missing Values: 0
# review_scores_location, Number of Missing Values: 0
# review_scores_value, Number of Missing Values: 0
# instant_bookable, Number of Missing Values: 0
# calculated_host_listings_count, Number of Missing Values: 0
# calculated_host_listings_count_entire_homes, Number of Missing Values: 0
# calculated_host_listings_count_private_rooms, Number of Missing Values: 0
# calculated_host_listings_count_shared_rooms, Number of Missing Values: 0
# reviews_per_month, Number of Missing Values: 0

# %%
#Handling the Outliers using IQR
# Calculate the IQR for each column
for cols in numeric_columns:
    Q1 = subset_df[cols].quantile(0.25)
    Q3 = subset_df[cols].quantile(0.75)
    IQR = Q3 - Q1

    # Define the threshold for outliers
    threshold = 1.5

    # Identify rows with outliers
    lower_bound = Q1 - threshold * IQR
    upper_bound = Q3 + threshold * IQR
    outliers = (subset_df[cols] < lower_bound) | (subset_df[cols] > upper_bound)

    subset_df[cols] = subset_df[cols].apply(lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))
    # subset_df[cols] = subset_df[cols].apply(lambda x: x if pd.isnull(x) else lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))
    # Remove rows with outliers
    #subset_df = subset_df[~outliers]

print(subset_df.columns)
# Now df_encoded contains the DataFrame with outliers removed
# Out:
# Index(['host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_listings_count', 'host_total_listings_count',
#        'host_has_profile_pic', 'host_identity_verified', 'property_type',
#        'room_type', 'accommodates', 'bedrooms', 'beds', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'has_availability', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
#checking for feature types
for col in subset_df.columns:
    data_type = subset_df[col].dtype
    print(f"The data type of column '{col}' is {data_type}.")
# Out:
# The data type of column 'host_response_time' is string.
# The data type of column 'host_response_rate' is float64.
# The data type of column 'host_acceptance_rate' is float64.
# The data type of column 'host_is_superhost' is string.
# The data type of column 'host_listings_count' is float64.
# The data type of column 'host_total_listings_count' is float64.
# The data type of column 'host_has_profile_pic' is string.
# The data type of column 'host_identity_verified' is string.
# The data type of column 'property_type' is string.
# The data type of column 'room_type' is string.
# The data type of column 'accommodates' is float64.
# The data type of column 'bedrooms' is float64.
# The data type of column 'beds' is float64.
# The data type of column 'price' is float64.
# The data type of column 'minimum_nights' is float64.
# The data type of column 'maximum_nights' is float64.
# The data type of column 'minimum_minimum_nights' is float64.
# The data type of column 'maximum_minimum_nights' is float64.
# The data type of column 'minimum_maximum_nights' is float64.
# The data type of column 'maximum_maximum_nights' is float64.
# The data type of column 'minimum_nights_avg_ntm' is float64.
# The data type of column 'maximum_nights_avg_ntm' is float64.
# The data type of column 'has_availability' is string.
# The data type of column 'availability_30' is int64.
# The data type of column 'availability_60' is int64.
# The data type of column 'availability_90' is int64.
# The data type of column 'availability_365' is int64.
# The data type of column 'number_of_reviews' is float64.
# The data type of column 'number_of_reviews_ltm' is float64.
# The data type of column 'number_of_reviews_l30d' is float64.
# The data type of column 'review_scores_rating' is float64.
# The data type of column 'review_scores_accuracy' is float64.
# The data type of column 'review_scores_cleanliness' is float64.
# The data type of column 'review_scores_checkin' is float64.
# The data type of column 'review_scores_communication' is float64.
# The data type of column 'review_scores_location' is float64.
# The data type of column 'review_scores_value' is float64.
# The data type of column 'instant_bookable' is string.
# The data type of column 'calculated_host_listings_count' is float64.
# The data type of column 'calculated_host_listings_count_entire_homes' is float64.
# The data type of column 'calculated_host_listings_count_private_rooms' is float64.
# The data type of column 'calculated_host_listings_count_shared_rooms' is float64.
# The data type of column 'reviews_per_month' is float64.

# %%
#differentiate categorical and numerical columns
numeric_columns = subset_df.select_dtypes(include=['int64', 'float64','Int64','Float64']).columns
categorical_columns = set(subset_df.columns) - set(numeric_columns)
print("numeric_columns-->",numeric_columns)
print("categorical_columns-->",categorical_columns)
print(subset_df.shape)
# Out:
# numeric_columns--> Index(['host_response_rate', 'host_acceptance_rate', 'host_listings_count',
#        'host_total_listings_count', 'accommodates', 'bedrooms', 'beds',
#        'price', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')
# categorical_columns--> {'host_is_superhost', 'instant_bookable', 'property_type', 'host_response_time', 'room_type', 'host_identity_verified', 'host_has_profile_pic', 'has_availability'}
# (61299, 43)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Compute the Correlation Matrix for Numerical and boolean Columns
correlation_matrix = subset_df[numeric_columns].corr()

#Visualize the correlation matrix as a heatmap
plt.figure(figsize=(20,18))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

corr_cols = correlation_matrix[abs(correlation_matrix['price']) > 0.2].index
for i in corr_cols:
    print("column names having correlation with price greater than 0.2-->\n",i)
# Out:
# column names having correlation with price greater than 0.2-->
#  accommodates
# column names having correlation with price greater than 0.2-->
#  bedrooms
# column names having correlation with price greater than 0.2-->
#  price

# %%
#OH encoding on features
prefix_dict = {
    'room_type':'en_room_type_',
    'host_identity_verified':'en_id_ver_',
    'host_response_time':'en_res_time_',
    'host_is_superhost':'en_issuperhost_',
    'has_availability':'en_available_',
    'instant_bookable':'en_bookable_',
    'property_type':'en_prop_type_',
    'host_has_profile_pic':'en_profilepic_'
}
cat_col=list(categorical_columns)
cat_col = [x for x in cat_col if x != 'host_location']
df_encoded = pd.get_dummies(subset_df, prefix=prefix_dict, columns=cat_col)
print(df_encoded)
# Out:
#         host_response_rate  host_acceptance_rate  host_listings_count
# 117133               100.0                  99.0                 41.0  \
# 117134               100.0                  83.0                  1.0
# 117135               100.0                  95.0                  2.0
# 117136               100.0                 100.0                  1.0
# 117138               100.0                 100.0                  1.0
# ...                    ...                   ...                  ...
# 197125               100.0                  86.0                 24.0
# 197126               100.0                  88.0                 17.0
# 197127               100.0                 100.0                  2.0
# 197129               100.0                 100.0                  1.0
# 197130               100.0                 100.0                  6.0
#
#         host_total_listings_count  accommodates  bedrooms  beds  price
# 117133                       52.0           7.0       1.0   6.0  285.0  \
# 117134                        3.0           4.0       2.0   2.0  139.0
# 117135                        2.0           6.0       3.0   3.0  285.0
# 117136                        2.0           4.0       2.0   2.0   93.0
# 117138                        1.0           4.0       1.0   1.0   83.0
# ...                           ...           ...       ...   ...    ...
# 197125                       30.0           2.0       1.0   1.0  285.0
# 197126                       53.0           6.0       3.0   4.0  100.0
# 197127                        3.0           2.0       1.0   1.0  100.0
# 197129                        2.0           7.0       3.5   5.0  100.0
# 197130                        6.0           6.0       3.0   4.0  285.0
#
#         minimum_nights  maximum_nights  ...  en_room_type__Entire home/apt
# 117133             1.0          1125.0  ...                           True  \
# 117134             3.0           365.0  ...                           True
# 117135             5.0            14.0  ...                           True
# 117136             3.0           365.0  ...                           True
# 117138             2.0           365.0  ...                           True
# ...                ...             ...  ...                            ...
# 197125             2.0           365.0  ...                           True
# 197126             1.0             3.0  ...                           True
# 197127             3.0            30.0  ...                           True
# 197129             2.0           365.0  ...                           True
# 197130             1.0            30.0  ...                           True
#
#         en_room_type__Hotel room  en_room_type__Private room
# 117133                     False                       False  \
# 117134                     False                       False
# 117135                     False                       False
# 117136                     False                       False
# 117138                     False                       False
# ...                          ...                         ...
# 197125                     False                       False
# 197126                     False                       False
# 197127                     False                       False
# 197129                     False                       False
# 197130                     False                       False
#
#         en_room_type__Shared room  en_id_ver__f  en_id_ver__t
# 117133                      False         False          True  \
# 117134                      False         False          True
# 117135                      False         False          True
# 117136                      False         False          True
# 117138                      False         False          True
# ...                           ...           ...           ...
# 197125                      False         False          True
# 197126                      False         False          True
# 197127                      False         False          True
# 197129                      False         False          True
# 197130                      False         False          True
#
#         en_profilepic__f  en_profilepic__t  en_available__f  en_available__t
# 117133             False              True            False             True
# 117134             False              True            False             True
# 117135             False              True            False             True
# 117136             False              True            False             True
# 117138             False              True            False             True
# ...                  ...               ...              ...              ...
# 197125             False              True            False             True
# 197126             False              True            False             True
# 197127             False              True            False             True
# 197129             False              True            False             True
# 197130             False              True            False             True
#
# [61299 rows x 155 columns]

# %%
df_encoded.to_csv("AirBnbupdated.csv",index=True)
df_encoded.head()
# Out:
#         host_response_rate  host_acceptance_rate  host_listings_count
# 117133               100.0                  99.0                 41.0  \
# 117134               100.0                  83.0                  1.0
# 117135               100.0                  95.0                  2.0
# 117136               100.0                 100.0                  1.0
# 117138               100.0                 100.0                  1.0
#
#         host_total_listings_count  accommodates  bedrooms  beds  price
# 117133                       52.0           7.0       1.0   6.0  285.0  \
# 117134                        3.0           4.0       2.0   2.0  139.0
# 117135                        2.0           6.0       3.0   3.0  285.0
# 117136                        2.0           4.0       2.0   2.0   93.0
# 117138                        1.0           4.0       1.0   1.0   83.0
#
#         minimum_nights  maximum_nights  ...  en_room_type__Entire home/apt
# 117133             1.0          1125.0  ...                           True  \
# 117134             3.0           365.0  ...                           True
# 117135             5.0            14.0  ...                           True
# 117136             3.0           365.0  ...                           True
# 117138             2.0           365.0  ...                           True
#
#         en_room_type__Hotel room  en_room_type__Private room
# 117133                     False                       False  \
# 117134                     False                       False
# 117135                     False                       False
# 117136                     False                       False
# 117138                     False                       False
#
#         en_room_type__Shared room  en_id_ver__f  en_id_ver__t
# 117133                      False         False          True  \
# 117134                      False         False          True
# 117135                      False         False          True
# 117136                      False         False          True
# 117138                      False         False          True
#
#         en_profilepic__f  en_profilepic__t  en_available__f  en_available__t
# 117133             False              True            False             True
# 117134             False              True            False             True
# 117135             False              True            False             True
# 117136             False              True            False             True
# 117138             False              True            False             True
#
# [5 rows x 155 columns]

# %%
# explore distribution of accommodates.
value_counts = subset_df['accommodates'].value_counts()

# %%
# visualize distribution of accommodates
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.bar(value_counts.index, value_counts.values)
plt.xlabel('Number of Accommodations')
plt.ylabel('Frequency')
plt.title('Bar of Accommodations')
plt.xlim(0, 20)
plt.show()

# %%
# explore distribution of beds
value_counts1 = subset_df['beds'].value_counts()

# %%
# visualize distribution of beds
import matplotlib.pyplot as plt
plt.bar(value_counts1.index, value_counts1.values)
plt.xlabel('Bed Count')
plt.ylabel('Frequency')
plt.title('Bar of Beds')
plt.xlim(0, 20)
plt.show()

# %%
print(df_encoded.shape)
# Out:
# (61299, 155)

# %%
#again taking numerical columns only after OH encoding
numcols = df_encoded.select_dtypes(include=['int64', 'float64','Int64','Float64']).columns
print(numcols)
# Out:
# Index(['host_response_rate', 'host_acceptance_rate', 'host_listings_count',
#        'host_total_listings_count', 'accommodates', 'bedrooms', 'beds',
#        'price', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
#scaling of data
from sklearn.preprocessing import StandardScaler

# Create a DataFrame to store scaled values
scaled_df = df_encoded.copy()

# Perform scaling on the columns_to_process
scaler = StandardScaler()

# Fit the scaler on the selected columns and transform the data
scaled_values = scaler.fit_transform(df_encoded[numcols])

# Update the scaled values in the scaled_df DataFrame
scaled_df[numcols] = scaled_values
print(scaled_df.shape)
# Out:
# (61299, 155)

# %%
from sklearn.preprocessing import MinMaxScaler

# Create a DataFrame to store normalized values
normalized_df = scaled_df.copy()

# Perform normalization on the numcols
scaler = MinMaxScaler()

# Fit the scaler on the selected columns and transform the data
normalized_values = scaler.fit_transform(scaled_df[numcols])

# Update the normalized values in the normalized_df DataFrame
normalized_df[numcols] = normalized_values

# %%
from sklearn.decomposition import PCA

# Initialize PCA
pca = PCA()

# Fit PCA on the normalized data
pca.fit(normalized_df[numcols])

# Calculate cumulative explained variance ratio
explained_variance_ratio_cumulative = pca.explained_variance_ratio_.cumsum()

# Determine the number of components needed for a desired explained variance threshold
desired_explained_variance = 0.95  #desired threshold [high info retention-[0.95 or above], balanced-[0.85-0.90], aggresive DR-[0.70-0.80]]
n_components = next(i for i, ratio in enumerate(explained_variance_ratio_cumulative, start=1) if ratio >= desired_explained_variance)


print(f"Number of components needed for {desired_explained_variance:.0%} explained variance: {n_components}")
# Out:
# Number of components needed for 95% explained variance: 17

# %%
numcols = normalized_df.select_dtypes(include=['int64', 'float64','Int64','Float64']).columns
# Select columns that are not in numcols
catcols = normalized_df.loc[:, ~normalized_df.columns.isin(numcols)]
print(catcols)


# Print data types of columns in catcols
for col in catcols.columns:
    print(f"Column '{col}' has data type: {catcols[col].dtype}")
# Out:
#         en_issuperhost__f  en_issuperhost__t  en_bookable__f  en_bookable__t
# 117133              False               True            True           False  \
# 117134               True              False            True           False
# 117135               True              False            True           False
# 117136               True              False            True           False
# 117138               True              False           False            True
# ...                   ...                ...             ...             ...
# 197125              False               True            True           False
# 197126              False               True            True           False
# 197127               True              False            True           False
# 197129               True              False            True           False
# 197130               True              False           False            True
#
#         en_prop_type__Barn  en_prop_type__Boat  en_prop_type__Bus
# 117133               False               False              False  \
# 117134               False               False              False
# 117135               False               False              False
# 117136               False               False              False
# 117138               False               False              False
# ...                    ...                 ...                ...
# 197125               False               False              False
# 197126               False               False              False
# 197127               False               False              False
# 197129               False               False              False
# 197130               False               False              False
#
#         en_prop_type__Camper/RV  en_prop_type__Campsite
# 117133                    False                   False  \
# 117134                    False                   False
# 117135                    False                   False
# 117136                    False                   False
# 117138                    False                   False
# ...                         ...                     ...
# 197125                    False                   False
# 197126                    False                   False
# 197127                    False                   False
# 197129                    False                   False
# 197130                    False                   False
#
#         en_prop_type__Casa particular  ...  en_room_type__Entire home/apt
# 117133                          False  ...                           True  \
# 117134                          False  ...                           True
# 117135                          False  ...                           True
# 117136                          False  ...                           True
# 117138                          False  ...                           True
# ...                               ...  ...                            ...
# 197125                          False  ...                           True
# 197126                          False  ...                           True
# 197127                          False  ...                           True
# 197129                          False  ...                           True
# 197130                          False  ...                           True
#
#         en_room_type__Hotel room  en_room_type__Private room
# 117133                     False                       False  \
# 117134                     False                       False
# 117135                     False                       False
# 117136                     False                       False
# 117138                     False                       False
# ...                          ...                         ...
# 197125                     False                       False
# 197126                     False                       False
# 197127                     False                       False
# 197129                     False                       False
# 197130                     False                       False
#
#         en_room_type__Shared room  en_id_ver__f  en_id_ver__t
# 117133                      False         False          True  \
# 117134                      False         False          True
# 117135                      False         False          True
# 117136                      False         False          True
# 117138                      False         False          True
# ...                           ...           ...           ...
# 197125                      False         False          True
# 197126                      False         False          True
# 197127                      False         False          True
# 197129                      False         False          True
# 197130                      False         False          True
#
#         en_profilepic__f  en_profilepic__t  en_available__f  en_available__t
# 117133             False              True            False             True
# 117134             False              True            False             True
# 117135             False              True            False             True
# 117136             False              True            False             True
# 117138             False              True            False             True
# ...                  ...               ...              ...              ...
# 197125             False              True            False             True
# 197126             False              True            False             True
# 197127             False              True            False             True
# 197129             False              True            False             True
# 197130             False              True            False             True
#
# [61299 rows x 120 columns]
# Column 'en_issuperhost__f' has data type: bool
# Column 'en_issuperhost__t' has data type: bool
# Column 'en_bookable__f' has data type: bool
# Column 'en_bookable__t' has data type: bool
# Column 'en_prop_type__Barn' has data type: bool
# Column 'en_prop_type__Boat' has data type: bool
# Column 'en_prop_type__Bus' has data type: bool
# Column 'en_prop_type__Camper/RV' has data type: bool
# Column 'en_prop_type__Campsite' has data type: bool
# Column 'en_prop_type__Casa particular' has data type: bool
# Column 'en_prop_type__Castle' has data type: bool
# Column 'en_prop_type__Cave' has data type: bool
# Column 'en_prop_type__Dome' has data type: bool
# Column 'en_prop_type__Earthen home' has data type: bool
# Column 'en_prop_type__Entire bungalow' has data type: bool
# Column 'en_prop_type__Entire cabin' has data type: bool
# Column 'en_prop_type__Entire chalet' has data type: bool
# Column 'en_prop_type__Entire condo' has data type: bool
# Column 'en_prop_type__Entire cottage' has data type: bool
# Column 'en_prop_type__Entire guest suite' has data type: bool
# Column 'en_prop_type__Entire guesthouse' has data type: bool
# Column 'en_prop_type__Entire home' has data type: bool
# Column 'en_prop_type__Entire home/apt' has data type: bool
# Column 'en_prop_type__Entire loft' has data type: bool
# Column 'en_prop_type__Entire place' has data type: bool
# Column 'en_prop_type__Entire rental unit' has data type: bool
# Column 'en_prop_type__Entire serviced apartment' has data type: bool
# Column 'en_prop_type__Entire timeshare' has data type: bool
# Column 'en_prop_type__Entire townhouse' has data type: bool
# Column 'en_prop_type__Entire vacation home' has data type: bool
# Column 'en_prop_type__Entire villa' has data type: bool
# Column 'en_prop_type__Farm stay' has data type: bool
# Column 'en_prop_type__Floor' has data type: bool
# Column 'en_prop_type__Houseboat' has data type: bool
# Column 'en_prop_type__Hut' has data type: bool
# Column 'en_prop_type__Island' has data type: bool
# Column 'en_prop_type__Lighthouse' has data type: bool
# Column 'en_prop_type__Private room' has data type: bool
# Column 'en_prop_type__Private room in barn' has data type: bool
# Column 'en_prop_type__Private room in bed and breakfast' has data type: bool
# Column 'en_prop_type__Private room in boat' has data type: bool
# Column 'en_prop_type__Private room in bungalow' has data type: bool
# Column 'en_prop_type__Private room in cabin' has data type: bool
# Column 'en_prop_type__Private room in camper/rv' has data type: bool
# Column 'en_prop_type__Private room in casa particular' has data type: bool
# Column 'en_prop_type__Private room in castle' has data type: bool
# Column 'en_prop_type__Private room in chalet' has data type: bool
# Column 'en_prop_type__Private room in condo' has data type: bool
# Column 'en_prop_type__Private room in cottage' has data type: bool
# Column 'en_prop_type__Private room in dome' has data type: bool
# Column 'en_prop_type__Private room in dorm' has data type: bool
# Column 'en_prop_type__Private room in earthen home' has data type: bool
# Column 'en_prop_type__Private room in farm stay' has data type: bool
# Column 'en_prop_type__Private room in guest suite' has data type: bool
# Column 'en_prop_type__Private room in guesthouse' has data type: bool
# Column 'en_prop_type__Private room in home' has data type: bool
# Column 'en_prop_type__Private room in hostel' has data type: bool
# Column 'en_prop_type__Private room in hut' has data type: bool
# Column 'en_prop_type__Private room in loft' has data type: bool
# Column 'en_prop_type__Private room in minsu' has data type: bool
# Column 'en_prop_type__Private room in nature lodge' has data type: bool
# Column 'en_prop_type__Private room in rental unit' has data type: bool
# Column 'en_prop_type__Private room in resort' has data type: bool
# Column 'en_prop_type__Private room in serviced apartment' has data type: bool
# Column 'en_prop_type__Private room in tent' has data type: bool
# Column 'en_prop_type__Private room in tiny home' has data type: bool
# Column 'en_prop_type__Private room in tower' has data type: bool
# Column 'en_prop_type__Private room in townhouse' has data type: bool
# Column 'en_prop_type__Private room in treehouse' has data type: bool
# Column 'en_prop_type__Private room in vacation home' has data type: bool
# Column 'en_prop_type__Private room in villa' has data type: bool
# Column 'en_prop_type__Private room in yurt' has data type: bool
# Column 'en_prop_type__Ranch' has data type: bool
# Column 'en_prop_type__Religious building' has data type: bool
# Column 'en_prop_type__Room in aparthotel' has data type: bool
# Column 'en_prop_type__Room in bed and breakfast' has data type: bool
# Column 'en_prop_type__Room in boutique hotel' has data type: bool
# Column 'en_prop_type__Room in heritage hotel' has data type: bool
# Column 'en_prop_type__Room in hostel' has data type: bool
# Column 'en_prop_type__Room in hotel' has data type: bool
# Column 'en_prop_type__Room in resort' has data type: bool
# Column 'en_prop_type__Room in serviced apartment' has data type: bool
# Column 'en_prop_type__Shared room' has data type: bool
# Column 'en_prop_type__Shared room in barn' has data type: bool
# Column 'en_prop_type__Shared room in bed and breakfast' has data type: bool
# Column 'en_prop_type__Shared room in boutique hotel' has data type: bool
# Column 'en_prop_type__Shared room in casa particular' has data type: bool
# Column 'en_prop_type__Shared room in condo' has data type: bool
# Column 'en_prop_type__Shared room in earthen home' has data type: bool
# Column 'en_prop_type__Shared room in guest suite' has data type: bool
# Column 'en_prop_type__Shared room in guesthouse' has data type: bool
# Column 'en_prop_type__Shared room in home' has data type: bool
# Column 'en_prop_type__Shared room in hostel' has data type: bool
# Column 'en_prop_type__Shared room in loft' has data type: bool
# Column 'en_prop_type__Shared room in rental unit' has data type: bool
# Column 'en_prop_type__Shared room in serviced apartment' has data type: bool
# Column 'en_prop_type__Shared room in tent' has data type: bool
# Column 'en_prop_type__Shared room in townhouse' has data type: bool
# Column 'en_prop_type__Shared room in vacation home' has data type: bool
# Column 'en_prop_type__Shared room in villa' has data type: bool
# Column 'en_prop_type__Shipping container' has data type: bool
# Column 'en_prop_type__Tent' has data type: bool
# Column 'en_prop_type__Tiny home' has data type: bool
# Column 'en_prop_type__Tower' has data type: bool
# Column 'en_prop_type__Treehouse' has data type: bool
# Column 'en_prop_type__Windmill' has data type: bool
# Column 'en_res_time__a few days or more' has data type: bool
# Column 'en_res_time__within a day' has data type: bool
# Column 'en_res_time__within a few hours' has data type: bool
# Column 'en_res_time__within an hour' has data type: bool
# Column 'en_room_type__Entire home/apt' has data type: bool
# Column 'en_room_type__Hotel room' has data type: bool
# Column 'en_room_type__Private room' has data type: bool
# Column 'en_room_type__Shared room' has data type: bool
# Column 'en_id_ver__f' has data type: bool
# Column 'en_id_ver__t' has data type: bool
# Column 'en_profilepic__f' has data type: bool
# Column 'en_profilepic__t' has data type: bool
# Column 'en_available__f' has data type: bool
# Column 'en_available__t' has data type: bool

# %%
# Convert categorical columns to boolean arrays using pd.get_dummies()
#catcols_boolean = pd.get_dummies(catcols, dtype=bool)

# Convert categorical columns to boolean arrays
for col in catcols.columns:
    if catcols[col].dtype == 'object' or catcols[col].dtype == 'uint8' :
        catcols.loc[:,col] = catcols[col].astype(pd.BooleanDtype())

# Print data types of columns in catcols
for col in catcols.columns:
    print(f"Column '{col}' has data type: {catcols[col].dtype}")
# Out:
# Column 'en_issuperhost__f' has data type: bool
# Column 'en_issuperhost__t' has data type: bool
# Column 'en_bookable__f' has data type: bool
# Column 'en_bookable__t' has data type: bool
# Column 'en_prop_type__Barn' has data type: bool
# Column 'en_prop_type__Boat' has data type: bool
# Column 'en_prop_type__Bus' has data type: bool
# Column 'en_prop_type__Camper/RV' has data type: bool
# Column 'en_prop_type__Campsite' has data type: bool
# Column 'en_prop_type__Casa particular' has data type: bool
# Column 'en_prop_type__Castle' has data type: bool
# Column 'en_prop_type__Cave' has data type: bool
# Column 'en_prop_type__Dome' has data type: bool
# Column 'en_prop_type__Earthen home' has data type: bool
# Column 'en_prop_type__Entire bungalow' has data type: bool
# Column 'en_prop_type__Entire cabin' has data type: bool
# Column 'en_prop_type__Entire chalet' has data type: bool
# Column 'en_prop_type__Entire condo' has data type: bool
# Column 'en_prop_type__Entire cottage' has data type: bool
# Column 'en_prop_type__Entire guest suite' has data type: bool
# Column 'en_prop_type__Entire guesthouse' has data type: bool
# Column 'en_prop_type__Entire home' has data type: bool
# Column 'en_prop_type__Entire home/apt' has data type: bool
# Column 'en_prop_type__Entire loft' has data type: bool
# Column 'en_prop_type__Entire place' has data type: bool
# Column 'en_prop_type__Entire rental unit' has data type: bool
# Column 'en_prop_type__Entire serviced apartment' has data type: bool
# Column 'en_prop_type__Entire timeshare' has data type: bool
# Column 'en_prop_type__Entire townhouse' has data type: bool
# Column 'en_prop_type__Entire vacation home' has data type: bool
# Column 'en_prop_type__Entire villa' has data type: bool
# Column 'en_prop_type__Farm stay' has data type: bool
# Column 'en_prop_type__Floor' has data type: bool
# Column 'en_prop_type__Houseboat' has data type: bool
# Column 'en_prop_type__Hut' has data type: bool
# Column 'en_prop_type__Island' has data type: bool
# Column 'en_prop_type__Lighthouse' has data type: bool
# Column 'en_prop_type__Private room' has data type: bool
# Column 'en_prop_type__Private room in barn' has data type: bool
# Column 'en_prop_type__Private room in bed and breakfast' has data type: bool
# Column 'en_prop_type__Private room in boat' has data type: bool
# Column 'en_prop_type__Private room in bungalow' has data type: bool
# Column 'en_prop_type__Private room in cabin' has data type: bool
# Column 'en_prop_type__Private room in camper/rv' has data type: bool
# Column 'en_prop_type__Private room in casa particular' has data type: bool
# Column 'en_prop_type__Private room in castle' has data type: bool
# Column 'en_prop_type__Private room in chalet' has data type: bool
# Column 'en_prop_type__Private room in condo' has data type: bool
# Column 'en_prop_type__Private room in cottage' has data type: bool
# Column 'en_prop_type__Private room in dome' has data type: bool
# Column 'en_prop_type__Private room in dorm' has data type: bool
# Column 'en_prop_type__Private room in earthen home' has data type: bool
# Column 'en_prop_type__Private room in farm stay' has data type: bool
# Column 'en_prop_type__Private room in guest suite' has data type: bool
# Column 'en_prop_type__Private room in guesthouse' has data type: bool
# Column 'en_prop_type__Private room in home' has data type: bool
# Column 'en_prop_type__Private room in hostel' has data type: bool
# Column 'en_prop_type__Private room in hut' has data type: bool
# Column 'en_prop_type__Private room in loft' has data type: bool
# Column 'en_prop_type__Private room in minsu' has data type: bool
# Column 'en_prop_type__Private room in nature lodge' has data type: bool
# Column 'en_prop_type__Private room in rental unit' has data type: bool
# Column 'en_prop_type__Private room in resort' has data type: bool
# Column 'en_prop_type__Private room in serviced apartment' has data type: bool
# Column 'en_prop_type__Private room in tent' has data type: bool
# Column 'en_prop_type__Private room in tiny home' has data type: bool
# Column 'en_prop_type__Private room in tower' has data type: bool
# Column 'en_prop_type__Private room in townhouse' has data type: bool
# Column 'en_prop_type__Private room in treehouse' has data type: bool
# Column 'en_prop_type__Private room in vacation home' has data type: bool
# Column 'en_prop_type__Private room in villa' has data type: bool
# Column 'en_prop_type__Private room in yurt' has data type: bool
# Column 'en_prop_type__Ranch' has data type: bool
# Column 'en_prop_type__Religious building' has data type: bool
# Column 'en_prop_type__Room in aparthotel' has data type: bool
# Column 'en_prop_type__Room in bed and breakfast' has data type: bool
# Column 'en_prop_type__Room in boutique hotel' has data type: bool
# Column 'en_prop_type__Room in heritage hotel' has data type: bool
# Column 'en_prop_type__Room in hostel' has data type: bool
# Column 'en_prop_type__Room in hotel' has data type: bool
# Column 'en_prop_type__Room in resort' has data type: bool
# Column 'en_prop_type__Room in serviced apartment' has data type: bool
# Column 'en_prop_type__Shared room' has data type: bool
# Column 'en_prop_type__Shared room in barn' has data type: bool
# Column 'en_prop_type__Shared room in bed and breakfast' has data type: bool
# Column 'en_prop_type__Shared room in boutique hotel' has data type: bool
# Column 'en_prop_type__Shared room in casa particular' has data type: bool
# Column 'en_prop_type__Shared room in condo' has data type: bool
# Column 'en_prop_type__Shared room in earthen home' has data type: bool
# Column 'en_prop_type__Shared room in guest suite' has data type: bool
# Column 'en_prop_type__Shared room in guesthouse' has data type: bool
# Column 'en_prop_type__Shared room in home' has data type: bool
# Column 'en_prop_type__Shared room in hostel' has data type: bool
# Column 'en_prop_type__Shared room in loft' has data type: bool
# Column 'en_prop_type__Shared room in rental unit' has data type: bool
# Column 'en_prop_type__Shared room in serviced apartment' has data type: bool
# Column 'en_prop_type__Shared room in tent' has data type: bool
# Column 'en_prop_type__Shared room in townhouse' has data type: bool
# Column 'en_prop_type__Shared room in vacation home' has data type: bool
# Column 'en_prop_type__Shared room in villa' has data type: bool
# Column 'en_prop_type__Shipping container' has data type: bool
# Column 'en_prop_type__Tent' has data type: bool
# Column 'en_prop_type__Tiny home' has data type: bool
# Column 'en_prop_type__Tower' has data type: bool
# Column 'en_prop_type__Treehouse' has data type: bool
# Column 'en_prop_type__Windmill' has data type: bool
# Column 'en_res_time__a few days or more' has data type: bool
# Column 'en_res_time__within a day' has data type: bool
# Column 'en_res_time__within a few hours' has data type: bool
# Column 'en_res_time__within an hour' has data type: bool
# Column 'en_room_type__Entire home/apt' has data type: bool
# Column 'en_room_type__Hotel room' has data type: bool
# Column 'en_room_type__Private room' has data type: bool
# Column 'en_room_type__Shared room' has data type: bool
# Column 'en_id_ver__f' has data type: bool
# Column 'en_id_ver__t' has data type: bool
# Column 'en_profilepic__f' has data type: bool
# Column 'en_profilepic__t' has data type: bool
# Column 'en_available__f' has data type: bool
# Column 'en_available__t' has data type: bool

# %%
'''from sklearn.model_selection import train_test_split

target_col = 'price'  # Name of the column to keep

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(normalized_df[numcols + catcols], normalized_df[target_col], test_size=0.2, random_state=42)

# Initialize PCA with the desired number of components
n_comps = 17  # Set the number of components you want
pca = PCA(n_components=n_comps)

# Fit and transform the training data using PCA
pca_result_train = pca.fit_transform(X_train)

# Transform the testing data using the PCA transformation learned from the training data
pca_result_test = pca.transform(X_test)

# Create DataFrames to store PCA results for training and testing sets
pca_df_train = pd.DataFrame(data=pca_result_train, columns=[f'PC{i+1}' for i in range(n_comps)])
pca_df_test = pd.DataFrame(data=pca_result_test, columns=[f'PC{i+1}' for i in range(n_comps)])

# Concatenate PCA results with the target column for both training and testing sets
final_pca_df_train = pd.concat([pca_df_train, y_train], axis=1)
final_pca_df_test = pd.concat([pca_df_test, y_test], axis=1)

# Now final_pca_df_train and final_pca_df_test contain the PCA results along with the target column for training and testing sets
print("Training set columns:", final_pca_df_train.columns)
print("Testing set columns:", final_pca_df_test.columns)'''
# Out:
# 'from sklearn.model_selection import train_test_split\n\ntarget_col = \'price\'  # Name of the column to keep\n\n# Split the data into training and testing sets\nX_train, X_test, y_train, y_test = train_test_split(normalized_df[numcols + catcols], normalized_df[target_col], test_size=0.2, random_state=42)\n\n# Initialize PCA with the desired number of components\nn_comps = 17  # Set the number of components you want\npca = PCA(n_components=n_comps)\n\n# Fit and transform the training data using PCA\npca_result_train = pca.fit_transform(X_train)\n\n# Transform the testing data using the PCA transformation learned from the training data\npca_result_test = pca.transform(X_test)\n\n# Create DataFrames to store PCA results for training and testing sets\npca_df_train = pd.DataFrame(data=pca_result_train, columns=[f\'PC{i+1}\' for i in range(n_comps)])\npca_df_test = pd.DataFrame(data=pca_result_test, columns=[f\'PC{i+1}\' for i in range(n_comps)])\n\n# Concatenate PCA results with the target column for both training and testing sets\nfinal_pca_df_train = pd.concat([pca_df_train, y_train], axis=1)\nfinal_pca_df_test = pd.concat([pca_df_test, y_test], axis=1)\n\n# Now final_pca_df_train and final_pca_df_test contain the PCA results along with the target column for training and testing sets\nprint("Training set columns:", final_pca_df_train.columns)\nprint("Testing set columns:", final_pca_df_test.columns)'

# %%
# Initialize PCA with the desired number of components
n_comps = 17   #Set the number of components you want
pca = PCA(n_components=n_comps)
# Fit and transform the normalized data using PCA
pca_result = pca.fit_transform(normalized_df[numcols])

# Create a DataFrame to store PCA results
pca_df = pd.DataFrame(data=pca_result, columns=[f'PC{i+1}' for i in range(n_components)])

# Concatenate PCA results with categorical columns from normalized_df
final_pca_df = pd.concat([normalized_df[catcols], pca_df], axis=1)

# Now final_pca_df contains the PCA results along with categorical columns
#print(final_pca_df.columns)

# %%
#seperating Features and target variables
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
X = normalized_df.loc[:, normalized_df.columns != 'price']
Y = normalized_df['price']
#splitting in train and test
X_train, X_test, y_train, y_test = train_test_split(X, Y,test_size=0.2, random_state=42)
# Print the shapes of the train and test sets
print("\nTrain data shape:", X_train.shape, y_train.shape)
print("\nTest data shape:", X_test.shape, y_test.shape)
# Out:
# Train data shape: (49039, 154) (49039,)
#
# Test data shape: (12260, 154) (12260,)

# %%
# Initialize and fit the preprocessing scaler on the training data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
# Apply the same transformation to the test data
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
# Initialize and train the model on the scaled training data
print("\nLR")
LR_model = LinearRegression()
LR_model.fit(X_train_scaled, y_train)
y_train_pred =LR_model.predict(X_train_scaled)
y_test_pred =LR_model.predict(X_test_scaled)
# Calculate Mean Squared Error (MSE) for train and test sets
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)
print("\nTrain MSE:", train_mse)
print("\nTest MSE:", test_mse)
# Calculate R-squared for train and test sets
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)
print("\nTrain R-squared:", train_r2)
print("\nTest R-squared:", test_r2)
# Out:
# LR
#
# Train MSE: 0.06192996959596259
#
# Test MSE: 1.9992189044153926e+19
#
# Train R-squared: 0.13025131910831145
#
# Test R-squared: -2.8041955834980598e+20

# %%
from sklearn.linear_model import ElasticNet
# Initialize and train the model on the scaled training data
print("\nElasticNET")
En_model = ElasticNet(alpha=0.1, l1_ratio=0.5)
En_model.fit(X_train_scaled, y_train)
y_train_pred =En_model.predict(X_train_scaled)
y_test_pred =En_model.predict(X_test_scaled)
# Calculate Mean Squared Error (MSE) for train and test sets
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)
print("\nTrain MSE:", train_mse)
print("\nTest MSE:", test_mse)
# Calculate R-squared for train and test sets
train_r2 = r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)
print("\nTrain R-squared:", train_r2)
print("\nTest R-squared:", test_r2)
# Out:
# ElasticNET
#
# Train MSE: 0.07019861760675783
#
# Test MSE: 0.07024840956707282
#
# Train R-squared: 0.014125867294498828
#
# Test R-squared: 0.014663779835795698

# %%
from sklearn.ensemble import RandomForestRegressor

# Initialize and fit the Random Forest Regressor model
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train, y_train)

# Predict on the test set
rf_y_pred = rf_model.predict(X_test)

# Evaluate the model
rf_mse = mean_squared_error(y_test, rf_y_pred)
rf_r2 = r2_score(y_test, rf_y_pred)

print("Random Forest Mean Squared Error:", rf_mse)
print("Random Forest R-squared:", rf_r2)
# Out:
# Random Forest Mean Squared Error: 0.04567369798938351
# Random Forest R-squared: 0.35935988849952494

# %%
from sklearn.ensemble import StackingRegressor

# Initialize a Stacking Regressor with the previous models as base models
estimators = [
    ('linear',LR_model),
    ('random_forest', rf_model),
    ('ElasticNet', En_model)
    # Add more base models here
]

stacked_model = StackingRegressor(estimators=estimators, final_estimator=LinearRegression())

# Fit the stacked model on the training data
stacked_model.fit(X_train, y_train)

# Predict on the test set
stacked_y_pred = stacked_model.predict(X_test)

# Evaluate the stacked model
stacked_mse = mean_squared_error(y_test, stacked_y_pred)
stacked_r2 = r2_score(y_test, stacked_y_pred)

print("Stacked Model Mean Squared Error:", stacked_mse)
print("Stacked Model R-squared:", stacked_r2)
# Out:
# Stacked Model Mean Squared Error: 0.04549732497625721
# Stacked Model R-squared: 0.36183377679342166

# %%
'''from lime.lime_tabular import LimeTabularExplainer
#import shap

# List of feature names (replace with your actual feature names)
feature_names = list(X_train.columns)

for i in feature_names:
    print(i)

# LIME explanation
lime_explainer = LimeTabularExplainer(X_train.values, mode='regression', feature_names=feature_names)
lime_explanation = lime_explainer.explain_instance(X_test.iloc[0], stacked_model.predict)
lime_explanation.show_in_notebook()

# SHAP explanation
shap_explainer = shap.Explainer(stacked_model)
shap_values = shap_explainer(X_test)
shap.plots.waterfall(shap_values[0])'''
# Out:
# "from lime.lime_tabular import LimeTabularExplainer\n#import shap\n\n# List of feature names (replace with your actual feature names)\nfeature_names = list(X_train.columns)\n\nfor i in feature_names:\n    print(i)\n\n# LIME explanation\nlime_explainer = LimeTabularExplainer(X_train.values, mode='regression', feature_names=feature_names)\nlime_explanation = lime_explainer.explain_instance(X_test.iloc[0], stacked_model.predict)\nlime_explanation.show_in_notebook()\n\n# SHAP explanation\nshap_explainer = shap.Explainer(stacked_model)\nshap_values = shap_explainer(X_test)\nshap.plots.waterfall(shap_values[0])"

# %%
from lime.lime_tabular import LimeTabularExplainer
from sklearn.metrics import mean_squared_error, r2_score

# List of feature names (replace with your actual feature names)
feature_names = list(X_train.columns)

# Initialize a LimeTabularExplainer with feature names
lime_explainer = LimeTabularExplainer(X_train.values, mode='regression', feature_names=feature_names)

# Select a specific instance from the test set for explanation
instance_to_explain = X_test.iloc[0]

# Explain the prediction of the stacked model using LIME
lime_explanation = lime_explainer.explain_instance(instance_to_explain, stacked_model.predict)

# Print the explanation
print("LIME Explanation for Stacked Model:")
explanation_text = lime_explanation.as_list()
for feature, weight in explanation_text:
    print(f"{feature}: {weight:.4f}")

# Display the explanation visualization in a notebook
lime_explanation.show_in_notebook()

# Predict on the test set using the stacked model
stacked_y_pred = stacked_model.predict(X_test)

# Evaluate the stacked model
stacked_mse = mean_squared_error(y_test, stacked_y_pred)
stacked_r2 = r2_score(y_test, stacked_y_pred)

print("Stacked Model Mean Squared Error:", stacked_mse)
print("Stacked Model R-squared:", stacked_r2)
# Out:
# i:\PythonInstallation\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# i:\PythonInstallation\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# i:\PythonInstallation\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but ElasticNet was fitted with feature names
#   warnings.warn(
# LIME Explanation for Stacked Model:
# en_res_time__within a few hours <= 0.00: -1.8313
# en_res_time__within a day <= 0.00: -1.7964
# en_res_time__a few days or more <= 0.00: -1.7743
# en_room_type__Private room <= 0.00: 1.4188
# en_room_type__Shared room <= 0.00: 1.3624
# en_room_type__Hotel room <= 0.00: 1.3292
# en_prop_type__Private room in nature lodge <= 0.00: 0.5845
# en_prop_type__Room in hostel <= 0.00: 0.5844
# en_prop_type__Shared room in condo <= 0.00: -0.5457
# en_prop_type__Shared room in casa particular <= 0.00: -0.4802
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# /******/ 		// Return the exports of the module
# /******/ 		return module.exports;
# /******/ 	}
# /******/
# /******/
# /******/ 	// expose the modules object (__webpack_modules__)
# /******/ 	__webpack_require__.m = modules;
# /******/
# /******/ 	// expose the module cache
# /******/ 	__webpack_require__.c = installedModules;
# /******/
# /******/ 	// __webpack_public_path__
# /******/ 	__webpack_require__.p = "";
# /******/
# /******/ 	// Load entry module and return exports
# /******/ 	return __webpack_require__(0);
# /******/ })
# /************************************************************************/
# /******/ ([
# /* 0 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	/* WEBPACK VAR INJECTION */(function(global) {'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
# 	exports.PredictedValue = exports.PredictProba = exports.Barchart = exports.Explanation = undefined;
#
# 	var _explanation = __webpack_require__(1);
#
# 	var _explanation2 = _interopRequireDefault(_explanation);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _predict_proba = __webpack_require__(6);
#
# 	var _predict_proba2 = _interopRequireDefault(_predict_proba);
#
# 	var _predicted_value = __webpack_require__(7);
#
# 	var _predicted_value2 = _interopRequireDefault(_predicted_value);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	if (!global._babelPolyfill) {
# 	  __webpack_require__(8);
# 	}
#
# 	__webpack_require__(339);
#
# 	exports.Explanation = _explanation2.default;
# 	exports.Barchart = _bar_chart2.default;
# 	exports.PredictProba = _predict_proba2.default;
# 	exports.PredictedValue = _predicted_value2.default;
# 	//require('style-loader');
# 	/* WEBPACK VAR INJECTION */}.call(exports, (function() { return this; }())))
#
# /***/ }),
# /* 1 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
#
# 	var _slicedToArray = function () { function sliceIterator(arr, i) { var _arr = []; var _n = true; var _d = false; var _e = undefined; try { for (var _i = arr[Symbol.iterator](), _s; !(_n = (_s = _i.next()).done); _n = true) { _arr.push(_s.value); if (i && _arr.length === i) break; } } catch (err) { _d = true; _e = err; } finally { try { if (!_n && _i["return"]) _i["return"](); } finally { if (_d) throw _e; } } return _arr; } return function (arr, i) { if (Array.isArray(arr)) { return arr; } else if (Symbol.iterator in Object(arr)) { return sliceIterator(arr, i); } else { throw new TypeError("Invalid attempt to destructure non-iterable instance"); } }; }();
#
# 	var _d2 = __webpack_require__(2);
#
# 	var _d3 = _interopRequireDefault(_d2);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _lodash = __webpack_require__(4);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	function _classCallCheck(instance, Constructor) { if (!(instance instanceof Constructor)) { throw new TypeError("Cannot call a class as a function"); } }
#
# 	var Explanation = function () {
# 	  function Explanation(class_names) {
# 	    _classCallCheck(this, Explanation);
#
# 	    this.names = class_names;
# 	    if (class_names.length < 10) {
# 	      this.colors = _d3.default.scale.category10().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category10().domain((0, _lodash.range)(this.names.length));
# 	    } else {
# 	      this.colors = _d3.default.scale.category20().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category20().domain((0, _lodash.range)(this.names.length));
# 	    }
# 	  }
# 	  // exp: [(feature-name, weight), ...]
# 	  // label: int
# 	  // div: d3 selection
#
#
# 	  Explanation.prototype.show = function show(exp, label, div) {
# 	    var svg = div.append('svg').style('width', '100%');
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    var names = ['NOT ' + this.names[label], this.names[label]];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	      names = this.names;
# 	    }
# 	    var plot = new _bar_chart2.default(svg, exp, true, names, colors, true, 10);
# 	    svg.style('height', plot.svg_height + 'px');
# 	  };
# 	  // exp has all ocurrences of words, with start index and weight:
# 	  // exp = [('word', 132, -0.13), ('word3', 111, 1.3)
#
#
# 	  Explanation.prototype.show_raw_text = function show_raw_text(exp, label, raw, div) {
# 	    var opacity = arguments.length > 4 && arguments[4] !== undefined ? arguments[4] : true;
#
# 	    //let colors=['#5F9EA0', this.colors(this.exp['class'])];
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var word_lists = [[], []];
# 	    var max_weight = -1;
# 	    var _iteratorNormalCompletion = true;
# 	    var _didIteratorError = false;
# 	    var _iteratorError = undefined;
#
# 	    try {
# 	      for (var _iterator = exp[Symbol.iterator](), _step; !(_iteratorNormalCompletion = (_step = _iterator.next()).done); _iteratorNormalCompletion = true) {
# 	        var _step$value = _slicedToArray(_step.value, 3),
# 	            word = _step$value[0],
# 	            start = _step$value[1],
# 	            weight = _step$value[2];
#
# 	        if (weight > 0) {
# 	          word_lists[1].push([start, start + word.length, weight]);
# 	        } else {
# 	          word_lists[0].push([start, start + word.length, -weight]);
# 	        }
# 	        max_weight = Math.max(max_weight, Math.abs(weight));
# 	      }
# 	    } catch (err) {
# 	      _didIteratorError = true;
# 	      _iteratorError = err;
# 	    } finally {
# 	      try {
# 	        if (!_iteratorNormalCompletion && _iterator.return) {
# 	          _iterator.return();
# 	        }
# 	      } finally {
# 	        if (_didIteratorError) {
# 	          throw _iteratorError;
# 	        }
# 	      }
# 	    }
#
# 	    if (!opacity) {
# 	      max_weight = 0;
# 	    }
# 	    this.display_raw_text(div, raw, word_lists, colors, max_weight, true);
# 	  };
# 	  // exp is list of (feature_name, value, weight)
#
#
# 	  Explanation.prototype.show_raw_tabular = function show_raw_tabular(exp, label, div) {
# 	    div.classed('lime', true).classed('table_div', true);
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var table = div.append('table');
# 	    var thead = table.append('tr');
# 	    thead.append('td').text('Feature');
# 	    thead.append('td').text('Value');
# 	    thead.style('color', 'black').style('font-size', '20px');
# 	    var _iteratorNormalCompletion2 = true;
# 	    var _didIteratorError2 = false;
# 	    var _iteratorError2 = undefined;
#
# 	    try {
# 	      for (var _iterator2 = exp[Symbol.iterator](), _step2; !(_iteratorNormalCompletion2 = (_step2 = _iterator2.next()).done); _iteratorNormalCompletion2 = true) {
# 	        var _step2$value = _slicedToArray(_step2.value, 3),
# 	            fname = _step2$value[0],
# 	            value = _step2$value[1],
# 	            weight = _s
# Stacked Model Mean Squared Error: 0.04549732497625721
# Stacked Model R-squared: 0.36183377679342166

# %%
import pickle
pickle.dump(stacked_model,open('fore.pkl','wb'))
